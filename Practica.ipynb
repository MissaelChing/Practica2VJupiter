# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams["figure.figsize"]=(16,9)
plt.style.use("ggplot")

dataframe = pd.read_csv("all_stocks_5yr.csv")
dataframe.head()

print(dataframe.groupby('Name').size())


dataframe.drop(['Name'],1).hist()
plt.show()

stocks_data = pd.read_csv('all_stocks_5yr.csv')
stocks_data = stocks_data.rename(columns={'Name':'symbol'})
stocks_data['date'] = pd.to_datetime(stocks_data['date'])
stocks_data.head()

def get_name(symbol):
    name = symbol
    try:
        name = companies.loc[symbol]['security']
    except KeyError:
        pass
    return name

def plot_stock(symbol, stocks=stocks):
    name = get_name(symbol)
    stocks[symbol].plot(title=name, label=name, alpha=0.9);
    
plot_stock('MSFT')
plot_stock('AAPL')
plt.title('')
plt.legend();


start = stocks.iloc[0]
returns = (stocks - start) / start
plt.figure(figsize = (20,8))
plot_stock('MSFT', stocks=returns)
plot_stock('AAPL', stocks=returns)
plt.title('')
plt.legend();
# Out:
# Name
# A       1259
# AAL     1259
# AAP     1259
# AAPL    1259
# ABBV    1259
#         ...
# XYL     1259
# YUM     1259
# ZBH     1259
# ZION    1259
# ZTS     1259
# Length: 505, dtype: int64
# C:\Users\Missael Ching Mendez\AppData\Local\Temp\ipykernel_17456\4177096960.py:19: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dataframe.drop(['Name'],1).hist()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 30>()
#      28 returns = (stocks - start) / start
#      29 plt.figure(figsize = (20,8))
# ---> 30 plot_stock('MSFT', stocks=returns)
#      31 plot_stock('AAPL', stocks=returns)
#      32 plt.title('')
#
# Input In [7], in plot_stock(symbol, stocks)
#      44 def plot_stock(symbol, stocks=stocks):
# ---> 45     name = get_name(symbol)
#      46     stocks[symbol].plot(title=name, label=name, alpha=0.9);
#      49     plot_stock('MSFT')
#
# Input In [7], in get_name(symbol)
#      37 name = symbol
#      38 try:
# ---> 39     name = companies.loc[symbol]['security']
#      40 except KeyError:
#      41     pass
#
# NameError: name 'companies' is not defined
